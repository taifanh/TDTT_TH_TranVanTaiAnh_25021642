# %%
# W6A1
a = list(map(int, input().split()))
b = []
for i in a:
    if i in b:
        pass
    else:
        b.append(i)
print(b)
# Out:
# [1, 2, 3]

# %%
# W6A2
a = list(map(int, input().split()))
b = list()
for i in range(len(a)):
    b.append(sum(a[:i + 1]))
print(b)

# %%
# W6A3
a = tuple(map(int, input().split()))
k = int(input())
while k:
    a = a[1:] + a[0:1]
    k -= 1
print(a)
# Out:
# (-4, -1, -2, -3)

# %%
# W6A4
def chia(s):
    for i in range(len(s)):
        if s[i] == ':':
            return (s[:i], s[i + 1:])
a = input().split()
d = {}
for x, y in [chia(x) for x in a]:
    if x in d:
        d[x].append(y)
    else:
        d[x] = [y]
print(d)
# Out:
# {'name': ['Alice', 'Bob'], 'age': ['20']}

# %%
# W6A5
a = list(map(int, input().split()))
d = {'positives': 0, 'negatives': 0, 'zero':0}
for x in a:
    if x == 0:
        d['zero'] += 1
    elif x < 0:
        d['negatives'] += 1
    else:
        d['positives'] += 1
print(d)
# Out:
# {'positives': 2, 'negatives': 2, 'zero': 3}

# %%
# W6A6
a = list(map(int, input().split()))
print(sum(a))
# Out:
# 6

# %%
# W6A7
a = tuple(input().split())
print(a[0], a[-1], a[::-1])
# Out:
# 5 4 ('4', '1', '7', '2', '8', '5')

# %%
# W6A8
a = input().split()
d = {}
for x in a:
    if x in d:
        d[x] += 1
    else:
        d[x] = 1
print(d)
# Out:
# {'5': 1, '8': 1, '2': 1, '7': 1, '1': 1, '4': 1}

# %%
# W6A9
import ast
a = ast.literal_eval(input())
b = ast.literal_eval(input())
c = {}
for x, y in a.items():
    if x in b:
        c[x] = y + b[x]
    else:
        c[x] = y
for x, y in b.items():
    if x not in a:
        c[x] = y
print(dict(sorted(c.items())))
# Out:
# Traceback (most recent call last):
#
#   File d:\Documents\uet\tdtt\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 3
#     a = ast.literal_eval(input())
#
#   File ~\AppData\Local\Programs\Python\Python313\Lib\ast.py:64 in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File ~\AppData\Local\Programs\Python\Python313\Lib\ast.py:50 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     5 8 2 7 1 4
#       ^
# SyntaxError: invalid syntax

# %%
# W6A10
a = list(map(int, input().split()))
k = int(input())
res = []
for i in range(len(a)):
    for j in range(i + 1, len(a)):
        if a[i] + a[j] == k:
            res.append((a[i], a[j]))
            break
res = list(set(res))
res.sort()
print(res)
# Out:
# [(1, 3), (2, 2), (3, 1)]

# %%
# W6A11
a = list(map(int, input().split()))
chan = ()
le = ()
for x in a:
    if x % 2 == 0:
        chan += (x, )
    else:
        le += (x, )
print(chan)
print(le)
# Out:
# (10, 2, 8, 4, 6)
# (1, 9, 3, 7, 5)

# %%
# W6A12
a = list(map(int, input().split()))
d = {}
res = (0, 0)
for x in a:
    if x not in d:
        d[x] = 1
    else:
        d[x] += 1
    res = max(res, (d[x], -x))
print(-res[1])
# Out:
# -3

# %%
# W6A13
a = input().split()
d = {}
for a, b in zip(a[::2], a[1::2]):
    d[b] = a
print(d)
# Out:
# {'1': 'a', '2': 'b', '3': 'c'}

# %%
# W6A14
a = set(map(int, input().split()))
b = set(map(int, input().split()))
c = list(a & b)
c.sort()
print(c)
# Out:
# [-1, 0, 1]

# %%
# W6A15
a = input().split()
k = int(input())
d = {}
for a, b in zip(a[::2], a[1::2]):
    if int(b) > k:
        d[a] = b
print(d)
# Out:
# {'apple': '10', 'banana': '20', 'orange': '15'}

# %%
# W6A16
n, m = map(int, input().split())

a = []
for _ in range(n):
    a.append(list(map(int, input().split())))

for i in range(n):
    for j in range(m):
        print(f"{a[i][j]:>4}", end="")
    print()
# Out:
#    1   2   3
#    1   2   3
#    1   2   3

# %%
# W6A17
n, m = map(int, input().split())
a = []
for i in range(n):
    a.append(list(map(int, input().split())))
for i in range(n):
    print(a[i][i], end = " ")
print('\n')

for i in range(n):
    print(a[i][n - i - 1], end = " ")
# print(a)
# Out:
# 1 2 3
#
# 3 2 1

# %%
# W6A18
n, m, k = map(int, input().split())
a = []
for i in range(n):
    a.append(list(map(int, input().split())))
tong = 0
for i in range(n):
    tong += a[i][k - 1]
print(tong)
# print(a)
# Out:
# 6
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
# W6A19
def cal(a):
    for i in range(len(a)):
        if a[i] == max(a):
            return i + 1
    return -1
a = list(map(int, input().split()))
print(cal(a))
# Out:
# 6

# %%
# W6A20
def check(a, k):
    for i in range(1, len(a)):
        if a[i - 1] == k:
            return i
    return -1
a = list(map(int, input().split()))
k = int(input())
print(check(a, k))
# Out:
# 5

# %%
# W6A21
a = input().split()
dct = {}
for i in range(len(a)):
    if a[i] in dct:
        dct[a[i]] += (i, )
    else:
        dct[a[i]] = (i, )
print(dct)
# Out:
# (1,)
# {'1': (0, 1, 2), '2': (3,)}

# %%
# W6A22
def cal(a):
    for i in range(len(a)):
        if a[i] == max(a):
            return i + 1
    return -1
a = list(map(int, input().split()))
print(cal(a))
# Out:
# 3
